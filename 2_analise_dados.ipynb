# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("diabetic_data_2.csv")
df = pd.DataFrame(data)
df
# Out:
#        age  time_in_hospital  num_lab_procedures  num_procedures  \
# 0       15                 3                  59               0
# 1       35                 2                  44               1
# 2       45                 1                  51               0
# 3       55                 3                  31               6
# 4       75                 5                  73               0
# ...    ...               ...                 ...             ...
# 91837   75                 3                  51               0
# 91838   85                 5                  33               3
# 91839   75                 1                  53               0
# 91840   85                10                  45               2
# 91841   75                 6                  13               3
#
#        num_medications  number_outpatient  number_emergency  number_inpatient  \
# 0                   18                  0                 0                 0
# ...

# %%
X = df.drop(["readmitted"], axis=1)
y = df["readmitted"]

# %%
index, counts = np.unique(y, return_counts=True)
colors = ["b", "r"]
plt.bar(index, counts, color=colors)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # PCA

# %%
pca = PCA(n_components=2)
X_r = pca.fit_transform(X)

colors = ['blue', 'red']
plt.figure(figsize=(10,8))
plt.scatter(X_r[y_r == 0, 0], X_r[y_r == 0, 1], color=colors[0], alpha=.8, label="0")
plt.scatter(X_r[y_r == 1, 0], X_r[y_r == 1, 1], color=colors[1], alpha=.8, label="1")
plt.legend(loc="best")
plt.title('PCA')
plt.show()

# %% [markdown]
# # PCA + Scaler

# %%
scaler = StandardScaler()
scaler.fit(X)
X_s = scaler.transform(X)

# %%
pca = PCA(n_components=2)
X_r = pca.fit_transform(X_s)

colors = ['blue', 'red']
plt.figure(figsize=(10,8))
plt.scatter(X_r[y_r == 0, 0], X_r[y_r == 0, 1], color=colors[0], alpha=.8, label="0")
plt.scatter(X_r[y_r == 1, 0], X_r[y_r == 1, 1], color=colors[1], alpha=.8, label="1")
plt.legend(loc="best")
plt.title('PCA')
plt.show()
